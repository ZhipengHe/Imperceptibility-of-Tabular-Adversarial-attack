# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a 2D grid of points
x = np.linspace(-3.0, 3.0, 100)
y = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(x, y)

# Define a function to simulate the adversarial loss landscape
Z = np.exp(-(X**2 + Y**2)) + 0.5 * np.exp(-((X - 2)**2 + (Y - 2)**2))

# Plot the contour
plt.contourf(X, Y, Z, levels=20, cmap='YlGnBu')

# # Define the paths for FGSM-RS and PGD
# # FGSM-RS path
# fgsm_rs_x = [-1, 1]
# fgsm_rs_y = [1, 0]
# plt.plot(fgsm_rs_x, fgsm_rs_y, 'ko-', label='FGSM-RS', lw=2)

# PGD path
pgd_x = [0.25, 0.5, 0.75, 1]
pgd_y = [0.75, 1, 1.25, 1.43]
plt.plot(pgd_x, pgd_y, 'ro-', label='PGD', lw=2)

# Mark key points with labels
plt.text(0, 0.75, r'$x^{0}$', fontsize=15)
# plt.text(1, 0, r'$x^{b}$', fontsize=12)
plt.text(1, 1.6, r'$x^{adv}$', fontsize=15)

# Display attack budget epsilon
plt.text(1.1, 0, r'$\epsilon$', fontsize=15)

# Display two classes
plt.text(0, -1.5, r'$C_1$', fontsize=15)
plt.text(2.5, 1, r'$C_2$', fontsize=15)

# add a decision boundary
plt.plot([-2, 4.25], [4, -1.75], 'k--', label='Decision Boundary', color='black')
plt.text(-1, 2.5, r'$f(x)$', fontsize=15)

# Plot a circle around point x as the attack budget epsilon
attack_budget_radius = 1  # Set the radius of the circle (epsilon)
circle = plt.Circle((0.25, 0.75), attack_budget_radius, color='gray', fill=False, linestyle='--', linewidth=1.5)
plt.gca().add_artist(circle)

# Remove axis labels, ticks, and borders
plt.gca().set_xticks([])  # Remove x-axis ticks
plt.gca().set_yticks([])  # Remove y-axis ticks
# plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['left'].set_visible(False)
# plt.gca().spines['bottom'].set_visible(False)

# Remove legend and title to maintain simplicity
plt.legend().set_visible(False)

# # set x aixs limit
plt.xlim(-2, 3)
plt.ylim(-2, 3)


plt.savefig("Visualisation/bounded_attack.png", dpi=300, bbox_inches = 'tight')
# Show the plot
plt.show()
# Out:
# C:\Users\n10599070\AppData\Local\Temp\ipykernel_39976\4104183638.py:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([-2, 4.25], [4, -1.75], 'k--', label='Decision Boundary', color='black')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a 2D grid of points
x = np.linspace(-3.0, 3.0, 100)
y = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(x, y)

# Define a function to simulate the adversarial loss landscape
Z = np.exp(-(X**2 + Y**2)) + 0.5 * np.exp(-((X - 2)**2 + (Y - 2)**2))

# Plot the contour
plt.contourf(X, Y, Z, levels=20, cmap='YlGnBu')

# # Define the paths for FGSM-RS and PGD
# FGSM-RS path
fgsm_rs_x = [0.25, 0.875]
fgsm_rs_y = [0.75, 1.38]
plt.plot(fgsm_rs_x, fgsm_rs_y, 'ro-', label='FGSM-RS', lw=2)

# PGD path
# pgd_x = [0.25, 0.5, 0.75, 1]
# pgd_y = [0.75, 1, 1.25, 1.43]
# plt.plot(pgd_x, pgd_y, 'ro-', label='PGD', lw=2)

# Mark key points with labels
plt.text(0, 0.75, r'$x^{0}$', fontsize=15)
# plt.text(1, 0, r'$x^{b}$', fontsize=12)
plt.text(1, 1.5, r'$x^{adv}$', fontsize=15)



# Display two classes
plt.text(0, -1.5, r'$C_1$', fontsize=15)
plt.text(2.5, 1, r'$C_2$', fontsize=15)

# add a decision boundary
plt.plot([-2, 4.25], [4, -1.75], 'k--', label='Decision Boundary', color='black')
plt.text(-1, 2.5, r'$f(x)$', fontsize=15)

# # Display attack budget epsilon
# plt.text(1.1, 0, r'$\epsilon$', fontsize=15)

# # Plot a circle around point x as the attack budget epsilon
# attack_budget_radius = 1  # Set the radius of the circle (epsilon)
# circle = plt.Circle((0.25, 0.75), attack_budget_radius, color='gray', fill=False, linestyle='--', linewidth=1.5)
# plt.gca().add_artist(circle)

# Remove axis labels, ticks, and borders
plt.gca().set_xticks([])  # Remove x-axis ticks
plt.gca().set_yticks([])  # Remove y-axis ticks
# plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['left'].set_visible(False)
# plt.gca().spines['bottom'].set_visible(False)

# Remove legend and title to maintain simplicity
plt.legend().set_visible(False)

# # set x aixs limit
plt.xlim(-2, 3)
plt.ylim(-2, 3)

plt.savefig("Visualisation/unbounded_attack.png", dpi=300, bbox_inches = 'tight')
# Show the plot
plt.show()
# Out:
# C:\Users\n10599070\AppData\Local\Temp\ipykernel_39976\3938519537.py:38: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([-2, 4.25], [4, -1.75], 'k--', label='Decision Boundary', color='black')

# %%
# Attack success rate for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Creating the dataset based on the extracted information
data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [84.95, 84.65, 84.75, 80.73, 76.56, 80.73,
             79.26, 80.82, 79.76, 75.0, 72.66, 75.78,
             96.88, 96.88, 98.44],
    'PGD': [84.95, 85.15, 84.75, 80.73, 78.65, 80.73,
            79.26, 80.89, 79.76, 75.0, 72.66, 75.78,
            96.88, 96.88, 98.44],
    'C&W': [69.86, 45.19, 14.76, 72.4, 61.98, 18.23,
            69.46, 72.09, 20.81, 75.0, 71.88, 25.78,
            90.63, 82.81, 4.69],
    'DeepFool': [82.69, 84.51, 85.32, 81.25, 80.73, 81.25,
                 79.33, 80.47, 79.76, 78.13, 72.66, 75.78,
                 98.44, 96.88, 98.44],
    'LowProFool': [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
                   np.nan, np.nan, np.nan, 75.78, 72.66, 75.78,
                   98.44, 96.88, 98.44]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f", vmin=0, vmax=100)
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/asr_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/asr_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()

# %%
from PIL import Image

# Step 2: Convert RGB to CMYK and save as PDF
rgb_image = Image.open("Visualisation/asr_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/asr_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'asr_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'asr_cmyk.pdf'.

# %%
# Attack success rate for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Extracted data
data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [0.5644, 0.5662, 0.5656, 0.5837, 0.5932, 0.5840,
             0.5289, 0.5187, 0.5314, 0.7842, 0.7939, 0.7808,
             1.5263, 1.4229, 1.4978],
    'PGD': [0.5644, 0.5663, 0.5656, 0.5837, 0.5826, 0.5840,
            0.5289, 0.5109, 0.5314, 0.7842, 0.7999, 0.7808,
            1.5263, 1.4672, 1.4978],
    'C&W': [0.5217, 0.1866, 0.0006, 0.6234, 0.4396, 0.0001,
            0.2426, 0.2459, 0.0017, 0.1942, 0.2114, 0.0091,
            0.4392, 0.2793, 0.0018],
    'DeepFool': [0.6355, 0.9627, 0.1108, 0.6435, 1.1269, 0.4128,
                 0.4108, 0.4637, 0.2360, 0.2719, 0.2912, 0.2305,
                 1.7005, 1.5350, 0.3923],
    'LowProFool': [None, None, None, None, None, None,
                   None, None, None, 0.7545, 0.6017, 0.6557,
                   1.3016, 1.7114, 0.9481]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f")
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/l2_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/l2_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()


# Step 2: Convert RGB to CMYK and save as PDF
rgb_image = Image.open("Visualisation/l2_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/l2_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'l2_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'l2_cmyk.pdf'.

# %%
# Linf for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Extracted data

data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [0.3000, 0.2999, 0.3000, 0.3000, 0.3000, 0.3000,
             0.3000, 0.3000, 0.3000, 0.3000, 0.3000, 0.3000,
             0.3000, 0.3000, 0.3000],
    'PGD': [0.3000, 0.3000, 0.3000, 0.3000, 0.3000, 0.3000,
            0.3000, 0.3000, 0.3000, 0.3000, 0.3000, 0.3000,
            0.3000, 0.3000, 0.3000],
    'C&W': [0.4081, 0.1570, 0.0005, 0.4146, 0.3569, 0.0001,
            0.2147, 0.2137, 0.0015, 0.1491, 0.1393, 0.0066,
            0.1854, 0.1502, 0.0009],
    'DeepFool': [0.4189, 0.4154, 0.1086, 0.3364, 0.4170, 0.3027,
                 0.3257, 0.3198, 0.1833, 0.1938, 0.1701, 0.1592,
                 0.5240, 0.5677, 0.1408],
    'LowProFool': [None, None, None, None, None, None,
                   None, None, None, 0.5228, 0.3471, 0.4548,
                   0.4537, 0.7110, 0.3485]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f", vmin=0, vmax=1)
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/linf_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/linf_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()

# Step 2: Convert RGB to CMYK and save as PDF

rgb_image = Image.open("Visualisation/linf_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/linf_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'linf_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'linf_cmyk.pdf'.

# %%
# Sparsity for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Extracted data

num_of_features = [102, 58, 23, 8, 30]

data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [3.6779, 3.6890, 3.6946, 4.3073, 4.4219, 4.3125,
             3.9311, 3.9197, 3.9361, 7.4375, 7.5391, 7.4609,
             29.9688, 29.8438, 29.9375],
    'PGD': [3.6779, 3.6920, 3.6946, 4.3073, 4.3281, 4.3125,
            3.9311, 3.9006, 3.9361, 7.4375, 7.6250, 7.4609,
            29.9688, 29.8594, 29.9375],
    'C&W': [3.7146, 3.0948, 2.0699, 5.0104, 4.7344, 3.6927,
            3.8040, 3.8111, 3.2003, 8.0000, 8.0000, 6.8438,
            29.8125, 29.8125, 29.7031],
    'DeepFool': [3.9497, 4.7433, 3.6946, 4.6458, 6.0000, 4.3125,
                 3.9382, 3.9929, 3.9361, 7.4375, 7.5391, 7.4609,
                 29.9688, 29.8438, 29.9375],
    'LowProFool': [None, None, None, None, None, None,
                   None, None, None, 7.4375, 7.5547, 7.4609,
                   29.9688, 29.9531, 29.9375]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Dataset is Adult then num_of_features[0] = 102, FGSM, PGD, C&W, DeepFool, LowProFool value = original value / num_of_features[0]
# Dataset is German then num_of_features[1] = 30, FGSM, PGD, C&W, DeepFool, LowProFool value = original value / num_of_features[1]
# Dataset is COMPAS then num_of_features[2] = 23, FGSM, PGD, C&W, DeepFool, LowProFool value = original value / num_of_features[2]
# Dataset is Diabetes then num_of_features[3] = 8, FGSM, PGD, C&W, DeepFool, LowProFool value = original value / num_of_features[3]
# Dataset is Breast Cancer then num_of_features[4] = 30, FGSM, PGD, C&W, DeepFool, LowProFool value = original value / num_of_features[4]
# Transform the data based on the number of features

for attack in ['FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']:
    df[attack] = df.apply(lambda x: x[attack] / num_of_features[0] if x['Dataset'] == 'Adult' else
    x[attack] / num_of_features[1] if x['Dataset'] == 'German' else
    x[attack] / num_of_features[2] if x['Dataset'] == 'COMPAS' else
    x[attack] / num_of_features[3] if x['Dataset'] == 'Diabetes' else
    x[attack] / num_of_features[4], axis=1)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f", vmin=0, vmax=1)
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/sparsity_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/sparsity_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()

# Step 2: Convert RGB to CMYK and save as PDF
rgb_image = Image.open("Visualisation/sparsity_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/sparsity_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'sparsity_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'sparsity_cmyk.pdf'.

# %%
# deviation for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Extracted data

data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [0.0787, 0.0779, 0.0788, 0.1519, 0.1654, 0.1521,
             0.0576, 0.0568, 0.0577, 0.1375, 0.1463, 0.1342,
             0.7075, 0.2807, 0.5639],
    'PGD': [0.0787, 0.0786, 0.0788, 0.1519, 0.1595, 0.1521,
            0.0576, 0.0563, 0.0577, 0.1375, 0.1492, 0.1342,
            0.7075, 0.3552, 0.5639],
    'C&W': [0.0773, 0.0277, 0.0001, 0.1540, 0.0999, 0.0000,
            0.0270, 0.0277, 0.0002, 0.0326, 0.0344, 0.0014,
            0.2088, 0.0623, 0.0006],
    'DeepFool': [0.1274, 0.2861, 0.0089, 0.2109, 0.4722, 0.0859,
                 0.0513, 0.0856, 0.0290, 0.0500, 0.0560, 0.0384,
                 0.8427, 0.4171, 0.1540],
    'LowProFool': [None, None, None, None, None, None,
                   None, None, None, 0.1365, 0.1128, 0.1081,
                   0.6694, 0.4691, 0.3788]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f", vmin=0, vmax=1)
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/deviation_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/deviation_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()

# Step 2: Convert RGB to CMYK and save as PDF

rgb_image = Image.open("Visualisation/deviation_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/deviation_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'deviation_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'deviation_cmyk.pdf'.

# %%
# sensitivity for different datasets and models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Extracted data

data = {
    'Dataset': ['Adult', 'Adult', 'Adult', 'German', 'German', 'German',
                'COMPAS', 'COMPAS', 'COMPAS', 'Diabetes', 'Diabetes', 'Diabetes',
                'Breast Cancer', 'Breast Cancer', 'Breast Cancer'],
    'Model': ['LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC', 'LR', 'MLP', 'LinearSVC',
              'LR', 'MLP', 'LinearSVC'],
    'FGSM': [2.4898, 2.4998, 2.5020, 1.1172, 1.1397, 1.1178,
             2.8215, 2.6871, 2.8485, 1.6910, 1.7464, 1.6867,
             1.9884, 1.8176, 1.9371],
    'PGD': [2.4898, 2.5019, 2.5020, 1.1172, 1.1130, 1.1178,
            2.8215, 2.5944, 2.8485, 1.6910, 1.7691, 1.6867,
            1.9884, 1.9000, 1.9371],
    'C&W': [1.5780, 0.4857, 0.0016, 1.0668, 0.6896, 0.0002,
            0.7602, 0.7803, 0.0047, 0.2931, 0.3613, 0.0147,
            0.3773, 0.2367, 0.0016],
    'DeepFool': [2.3923, 2.6746, 0.4252, 0.9765, 1.0908, 0.8187,
                 1.6436, 1.8902, 0.9090, 0.4780, 0.5704, 0.4114,
                 1.8599, 1.6574, 0.4496],
    'LowProFool': [None, None, None, None, None, None,
                   None, None, None, 1.3519, 1.1873, 1.1751,
                   1.3337, 1.8253, 1.0620]
}


# Convert to DataFrame
df = pd.DataFrame(data)

# Create a combined column for Dataset and Model
df['Dataset_Model'] = df['Dataset'] + ' - ' + df['Model']

pivot_df = df[['Dataset_Model', 'FGSM', 'PGD', 'C&W', 'DeepFool', 'LowProFool']]

# plot the heatmap
sns.set_theme(style='white')
plt.figure(figsize=(7, 8))
ax = sns.heatmap(pivot_df.set_index('Dataset_Model'), annot=True, linewidth=.5, cmap='coolwarm', fmt=".2f", vmin=0, vmax=1)
ax.set(xlabel="", ylabel="")
# plt.title('Accuracy of Different Attacks on Different Models and Datasets')
# plt.show()

plt.savefig("Visualisation/sensitivity_rgb.png", dpi=300, bbox_inches = 'tight')  # Save as PNG in RGB
plt.savefig("Visualisation/sensitivity_rgb.pdf", format='pdf', dpi=300, bbox_inches = 'tight')  # Save as PDF in RGB
plt.close()

# Step 2: Convert RGB to CMYK and save as PDF

rgb_image = Image.open("Visualisation/sensitivity_rgb.png")
cmyk_image = rgb_image.convert("CMYK")

# Save the CMYK image as a PDF
cmyk_image.save("Visualisation/sensitivity_cmyk.pdf", "PDF")

print("Plot saved in CMYK mode as 'sensitivity_cmyk.pdf'.")
# Out:
# Plot saved in CMYK mode as 'sensitivity_cmyk.pdf'.
