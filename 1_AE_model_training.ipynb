# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from utils.df_loader import (
    load_adult_df,
    load_compas_df,
    load_german_df,
    load_diabetes_df,
    load_breast_cancer_df,
)
from sklearn.model_selection import train_test_split
from utils.preprocessing import preprocess_df
from utils.models import (
    train_models,
    evaluation_test,
    save_models,
    load_models,
    save_model_performance,
)

seed = 42
# tf.random.set_seed(seed)
# np.random.seed(seed)

# %%
import warnings

pd.options.mode.chained_assignment = None # suppress "SettingWithCopyWarning" warning

# %%
num_instances = 64 # (1)&(2) 64 - 1 batch

TRAIN_MODEL = False # (1)True(2)False

# %%
tf.compat.v1.disable_eager_execution()
print("TF version: ", tf.__version__)
print("Eager execution enabled: ", tf.executing_eagerly())  # False
# Out:
# TF version:  2.10.0
# Eager execution enabled:  False

# %%
dataset = [
    "adult",
    "german",
    "compas",
    "diabetes",
    "breast_cancer",
    ]

performance_list = []

#### Select dataset ####
for dataset_name in dataset: 
    print(f"Dataset Name: [{dataset_name}]")
    if dataset_name == "adult":
        dataset_loading_fn = load_adult_df
    elif dataset_name == "german":
        dataset_loading_fn = load_german_df
    elif dataset_name == "compas":
        dataset_loading_fn = load_compas_df
    elif dataset_name == "diabetes":
        dataset_loading_fn = load_diabetes_df
    elif dataset_name == "breast_cancer":
        dataset_loading_fn = load_breast_cancer_df
    else:
        raise Exception("Unsupported dataset")

    df_info = preprocess_df(dataset_loading_fn)

    train_df, test_df = train_test_split(
        df_info.dummy_df, train_size=0.8, random_state=seed, shuffle=True
    )
    X_train = np.array(train_df[df_info.ohe_feature_names])
    y_train = np.array(train_df[df_info.target_name])
    X_test = np.array(test_df[df_info.ohe_feature_names])
    y_test = np.array(test_df[df_info.target_name])

    if TRAIN_MODEL:
        ## Train models.
        models = train_models(X_train, y_train)
        ## Save models.
        save_models(models, dataset_name)

    ### Load models
    models = load_models(X_train.shape[-1], dataset_name)

    ### Print out accuracy on testset.
    evaluation_test(models, X_test, y_test)

    performance_list.append(save_model_performance(models, dataset_name, X_test, y_test))
# Out:
# Dataset Name: [adult]
# c:\Users\n10599070\Miniconda3\envs\xai\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Model: [Decision Tree] | Accuracy: [0.8239] | Precision: [0.6375 | Recall: [0.6257] | F1: [0.6315]
# Model: [Random Forest] | Accuracy: [0.8472] | Precision: [0.7111 | Recall: [0.6174] | F1: [0.6610]
# Model: [Linear Support Vector Classification] | Accuracy: [0.8535] | Precision: [0.7474 | Recall: [0.5933] | F1: [0.6615]
# Model: [Logistic Regression] | Accuracy: [0.8526] | Precision: [0.7381 | Recall: [0.6028] | F1: [0.6636]
# Model: [Gradient Boosting] | Accuracy: [0.8680] | Precision: [0.8078 | Recall: [0.5939] | F1: [0.6845]
# Model: [Neural Network (single output unit)] | Accuracy: [0.8528] | Precision: [0.7146 | Recall: [0.6486] | F1: [0.6800]
# Model: [Neural Network (two output units)] | Accuracy: [0.8523] | Precision: [0.7450 | Recall: [0.5894] | F1: [0.6581]
# Dataset Name: [german]
# c:\Users\n10599070\Miniconda3\envs\xai\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Model: [Decision Tree] | Accuracy: [0.6900] | Precision: [0.4737 | Recall: [0.4576] | F1: [0.4655]
# Model: [Random Forest] | Accuracy: [0.7700] | Precision: [0.7097 | Recall: [0.3729] | F1: [0.4889]
# Model: [Linear Support Vector Classification] | Accuracy: [0.8050] | Precision: [0.7083 | Recall: [0.5763] | F1: [0.6355]
# Model: [Logistic Regression] | Accuracy: [0.8050] | Precision: [0.7083 | Recall: [0.5763] | F1: [0.6355]
# Model: [Gradient Boosting] | Accuracy: [0.7900] | Precision: [0.7073 | Recall: [0.4915] | F1: [0.5800]
# Model: [Neural Network (single output unit)] | Accuracy: [0.7700] | Precision: [0.6383 | Recall: [0.5085] | F1: [0.5660]
# Model: [Neural Network (two output units)] | Accuracy: [0.7900] | Precision: [0.6667 | Recall: [0.5763] | F1: [0.6182]
# Dataset Name: [compas]
# c:\Users\n10599070\Miniconda3\envs\xai\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Model: [Decision Tree] | Accuracy: [0.7186] | Precision: [0.8085 | Recall: [0.8008] | F1: [0.8046]
# Model: [Random Forest] | Accuracy: [0.7838] | Precision: [0.8285 | Recall: [0.8841] | F1: [0.8554]
# Model: [Linear Support Vector Classification] | Accuracy: [0.7997] | Precision: [0.8148 | Recall: [0.9358] | F1: [0.8712]
# Model: [Logistic Regression] | Accuracy: [0.7956] | Precision: [0.8166 | Recall: [0.9253] | F1: [0.8675]
# Model: [Gradient Boosting] | Accuracy: [0.8164] | Precision: [0.8384 | Recall: [0.9243] | F1: [0.8793]
# Model: [Neural Network (single output unit)] | Accuracy: [0.8032] | Precision: [0.8215 | Recall: [0.9301] | F1: [0.8724]
# Model: [Neural Network (two output units)] | Accuracy: [0.8108] | Precision: [0.8275 | Recall: [0.9330] | F1: [0.8771]
# Dataset Name: [diabetes]
# c:\Users\n10599070\Miniconda3\envs\xai\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Model: [Decision Tree] | Accuracy: [0.7468] | Precision: [0.6250 | Recall: [0.7273] | F1: [0.6723]
# Model: [Random Forest] | Accuracy: [0.7208] | Precision: [0.6071 | Recall: [0.6182] | F1: [0.6126]
# Model: [Linear Support Vector Classification] | Accuracy: [0.7662] | Precision: [0.6727 | Recall: [0.6727] | F1: [0.6727]
# Model: [Logistic Regression] | Accuracy: [0.7662] | Precision: [0.7111 | Recall: [0.5818] | F1: [0.6400]
# Model: [Gradient Boosting] | Accuracy: [0.7403] | Precision: [0.6271 | Recall: [0.6727] | F1: [0.6491]
# Model: [Neural Network (single output unit)] | Accuracy: [0.7078] | Precision: [0.5781 | Recall: [0.6727] | F1: [0.6218]
# Model: [Neural Network (two output units)] | Accuracy: [0.7532] | Precision: [0.6667 | Recall: [0.6182] | F1: [0.6415]
# Dataset Name: [breast_cancer]
# c:\Users\n10599070\Miniconda3\envs\xai\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Model: [Decision Tree] | Accuracy: [0.9474] | Precision: [0.9302 | Recall: [0.9302] | F1: [0.9302]
# Model: [Random Forest] | Accuracy: [0.9649] | Precision: [0.9756 | Recall: [0.9302] | F1: [0.9524]
# Model: [Linear Support Vector Classification] | Accuracy: [0.9737] | Precision: [0.9762 | Recall: [0.9535] | F1: [0.9647]
# Model: [Logistic Regression] | Accuracy: [0.9825] | Precision: [1.0000 | Recall: [0.9535] | F1: [0.9762]
# Model: [Gradient Boosting] | Accuracy: [0.9561] | Precision: [0.9524 | Recall: [0.9302] | F1: [0.9412]
# Model: [Neural Network (single output unit)] | Accuracy: [0.9561] | Precision: [0.9524 | Recall: [0.9302] | F1: [0.9412]
# Model: [Neural Network (two output units)] | Accuracy: [0.9737] | Precision: [0.9545 | Recall: [0.9767] | F1: [0.9655]

# %%
model_performance_table = pd.concat([pd.DataFrame.from_dict(k) for k in (performance_list)])
model_performance_table.to_csv(f"./saved_models/model_performance_table.csv",index=False)

# %%
model_performance_table
# Out:
#     Dataset Name Model Name  Accuracy  Precision    Recall  F1 Score
# 0          adult         dt  0.823891   0.637484  0.625716  0.631545
# 1          adult        rfc  0.847229   0.711144  0.617441  0.660988
# 2          adult        svc  0.853524   0.747394  0.593253  0.661462
# 3          adult         lr  0.852602   0.738114  0.602801  0.663630
# 4          adult        gbc  0.867956   0.807792  0.593889  0.684519
# 5          adult         nn  0.852756   0.714586  0.648631  0.680013
# 6          adult       nn_2  0.852295   0.744972  0.589433  0.658138
# 0         german         dt  0.690000   0.473684  0.457627  0.465517
# 1         german        rfc  0.770000   0.709677  0.372881  0.488889
# 2         german        svc  0.805000   0.708333  0.576271  0.635514
# 3         german         lr  0.805000   0.708333  0.576271  0.635514
# 4         german        gbc  0.790000   0.707317  0.491525  0.580000
# 5         german         nn  0.770000   0.638298  0.508475  0.566038
# 6         german       nn_2  0.790000   0.666667  0.576271  0.618182
# 0         compas         dt  0.718642   0.808511  0.800766  0.804620
# 1         compas        rfc  0.783784   0.828546  0.884100  0.855422
# 2         compas        svc  0.799723   0.814846  0.935824  0.871155
# 3         compas         lr  0.795565   0.816568  0.925287  0.867535
# 4         compas        gbc  0.816355   0.838401  0.924330  0.879271
# 5         compas         nn  0.803188   0.821489  0.930077  0.872417
# 6         compas       nn_2  0.810811   0.827528  0.932950  0.877082
# 0       diabetes         dt  0.746753   0.625000  0.727273  0.672269
# 1       diabetes        rfc  0.720779   0.607143  0.618182  0.612613
# 2       diabetes        svc  0.766234   0.672727  0.672727  0.672727
# 3       diabetes         lr  0.766234   0.711111  0.581818  0.640000
# 4       diabetes        gbc  0.740260   0.627119  0.672727  0.649123
# 5       diabetes         nn  0.707792   0.578125  0.672727  0.621849
# 6       diabetes       nn_2  0.753247   0.666667  0.618182  0.641509
# 0  breast_cancer         dt  0.947368   0.930233  0.930233  0.930233
# 1  breast_cancer        rfc  0.964912   0.975610  0.930233  0.952381
# 2  breast_cancer        svc  0.973684   0.976190  0.953488  0.964706
# 3  breast_cancer         lr  0.982456   1.000000  0.953488  0.976190
# 4  breast_cancer        gbc  0.956140   0.952381  0.930233  0.941176
# 5  breast_cancer         nn  0.956140   0.952381  0.930233  0.941176
# 6  breast_cancer       nn_2  0.973684   0.954545  0.976744  0.965517
